# %% [markdown]
# Q1. Create an empty list.
#
# A1. my_list = []

# %% [markdown]
# Q2. Create a list and add an element to the end of this list.
#
# A2. # Create a list
# my_list = [1, 2, 3, 4, 5]
#
# # Add an element to the end of the list
# my_list.append(6)
#
# # Print the updated list
# print(my_list)  # Output: [1, 2, 3, 4, 5, 6]

# %% [markdown]
# Q3. For the above created list print the last element.
#
# A3. # Create a list
# my_list = [1, 2, 3, 4, 5, 6]
#
# # Print the last element of the list
# print(my_list[-1])  # Output: 6

# %% [markdown]
# Q4. Reverse the above created list.
#
# A4. # Create a list
# my_list = [1, 2, 3, 4, 5, 6]
#
# # Reverse the list
# my_list.reverse()
#
# # Print the reversed list
# print(my_list)  # Output: [6, 5, 4, 3, 2, 1]

# %% [markdown]
# Q5. Sort the above created list.
#
# A5. # Create a list
# my_list = [4, 2, 6, 1, 3, 5]
#
# # Sort the list
# my_list.sort()
#
# # Print the sorted list
# print(my_list)  # Output: [1, 2, 3, 4, 5, 6]

# %% [markdown]
# Q6. Create a list of your top three favorite movies, then print the second movie title.
#
# A6. # Create a list of top three favorite movies
# my_movies = ["The Godfather", "The Shawshank Redemption", "The Dark Knight"]
#
# # Print the second movie title
# print(my_movies[1])  # Output: The Shawshank Redemption

# %% [markdown]
# Q7. Create a list of your favorite animals, then add a new animal to the list and print the updated list.
#
# A7. # Create a list of favorite animals
# my_animals = ["dog", "cat", "penguin"]
#
# # Add a new animal to the list
# my_animals.append("otter")
#
# # Print the updated list
# print(my_animals)  # Output: ['dog', 'cat', 'penguin', 'otter']

# %% [markdown]
# Q8. Create a list of your favorite cities, then use the index() method to find the position of a specific city
# on the list and print it.
#
# A8. # Create a list of favorite cities
# my_cities = ["New York", "London", "Tokyo", "Paris", "Los Angeles"]
#
# # Find the position of "Paris" in the list
# position = my_cities.index("Paris")
#
# # Print the position of "Paris"
# print(position)  # Output: 3
