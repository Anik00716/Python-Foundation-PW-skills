# %%
s={}

# %%
type(s)
# Out:
# dict

# %%
s={2,3,4,32,2}

# %%
type(s)
# Out:
# set

# %%
d={}

# %%
type(d)
# Out:
# dict

# %%
d={'a':1}

# %%
a=1

# %%
d
# Out:
# {'a': 1}

# %%
d1={'name':'sudh'}

# %%
d1['name']
# Out:
# 'sudh'

# %%
l=[3,4,5,6]

# %%
l[2]
# Out:
# 5

# %%
d2={234234:"sudh"}

# %%
d2[234234]
# Out:
# 'sudh'

# %%
d3={_234234:"sudh"}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_27/2426472196.py in <module>
# ----> 1 d3={_234234:"sudh"}
#
# NameError: name '_234234' is not defined

# %%
d4={[1,2,3]:"sudh"}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_27/3887828759.py in <module>
# ----> 1 d4={[1,2,3]:"sudh"}
#
# TypeError: unhashable type: 'list'

# %%
d5={(1,2,3):"sudh"}

# %%
d5[(1,2,3)]
# Out:
# 'sudh'

# %%
d5={{1,2,3}:"sudh"}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_27/697869951.py in <module>
# ----> 1 d5={{1,2,3}:"sudh"}
#
# TypeError: unhashable type: 'set'

# %%
d6={True:"sudh"}

# %%
d6={{345:'kumar'}:"sudh"}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_27/1784297197.py in <module>
# ----> 1 d6={{345:'kumar'}:"sudh"}
#
# TypeError: unhashable type: 'dict'

# %%
 d7={"name":"sudh","name":"pwskills"}

# %%
d7
# Out:
# {'name': 'pwskills'}

# %% [markdown]
# Key will be never duplicate

# %%
 d8={"name":"sudh","email_id":"sudh@gmail.com","subject":['DSM','big data','data analytics','programming']}

# %%
d8
# Out:
# {'name': 'sudh',
#  'email_id': 'sudh@gmail.com',
#  'subject': ['DSM', 'big data', 'data analytics', 'programming']}

# %%
'DSM' in d8['subject']
# Out:
# True

# %%
d8['subject'][1]
# Out:
# 'big data'

# %%
 d9={"name":"sudh","email_id":"sudh@gmail.com","subject":['DSM','big data','data analytics','programming'],'batches':('DSM','JDS','FSWD'),'Mentor':{'sudhanshu','krish','vishwa mohan','sanket','hyder','nitin','vishwa mohan','anurag','hitesh'},'date':{'FSDS':"29th april 23","DSM":"6th may23","JDS":"13th may23"}}

# %%
d9
# Out:
# {'name': 'sudh',
#  'email_id': 'sudh@gmail.com',
#  'subject': ['DSM', 'big data', 'data analytics', 'programming'],
#  'batches': ('DSM', 'JDS', 'FSWD'),
#  'Mentor': {'anurag',
#   'hitesh',
#   'hyder',
#   'krish',
#   'nitin',
#   'sanket',
#   'sudhanshu',
#   'vishwa mohan'},
#  'date': {'FSDS': '29th april 23', 'DSM': '6th may23', 'JDS': '13th may23'}}

# %%
d9['date']['DSM']
# Out:
# '6th may23'

# %%
d9['batch name']='BINARY 2.0'

# %%
d9
# Out:
# {'name': 'sudh',
#  'email_id': 'sudh@gmail.com',
#  'subject': ['DSM', 'big data', 'data analytics', 'programming'],
#  'batches': ('DSM', 'JDS', 'FSWD'),
#  'Mentor': {'anurag',
#   'hitesh',
#   'hyder',
#   'krish',
#   'nitin',
#   'sanket',
#   'sudhanshu',
#   'vishwa mohan'},
#  'date': {'FSDS': '29th april 23', 'DSM': '6th may23', 'JDS': '13th may23'},
#  'batch name': 'BINARY 2.0'}

# %%
d9['email_id']='su@pwskills.com'

# %%
d9
# Out:
# {'name': 'sudh',
#  'email_id': 'su@pwskills.com',
#  'subject': ['DSM', 'big data', 'data analytics', 'programming'],
#  'batches': ('DSM', 'JDS', 'FSWD'),
#  'Mentor': {'anurag',
#   'hitesh',
#   'hyder',
#   'krish',
#   'nitin',
#   'sanket',
#   'sudhanshu',
#   'vishwa mohan'},
#  'date': {'FSDS': '29th april 23', 'DSM': '6th may23', 'JDS': '13th may23'},
#  'batch name': 'BINARY 2.0'}

# %%
del d9['email_id']

# %%
d9
# Out:
# {'name': 'sudh',
#  'subject': ['DSM', 'big data', 'data analytics', 'programming'],
#  'batches': ('DSM', 'JDS', 'FSWD'),
#  'Mentor': {'anurag',
#   'hitesh',
#   'hyder',
#   'krish',
#   'nitin',
#   'sanket',
#   'sudhanshu',
#   'vishwa mohan'},
#  'date': {'FSDS': '29th april 23', 'DSM': '6th may23', 'JDS': '13th may23'},
#  'batch name': 'BINARY 2.0'}

# %%
list(d9.keys())
# Out:
# ['name', 'subject', 'batches', 'Mentor', 'date', 'batch name']

# %%
list(d9.values())
# Out:
# ['sudh',
#  ['DSM', 'big data', 'data analytics', 'programming'],
#  ('DSM', 'JDS', 'FSWD'),
#  {'anurag',
#   'hitesh',
#   'hyder',
#   'krish',
#   'nitin',
#   'sanket',
#   'sudhanshu',
#   'vishwa mohan'},
#  {'FSDS': '29th april 23', 'DSM': '6th may23', 'JDS': '13th may23'},
#  'BINARY 2.0']

# %%
list(d9.items())
# Out:
# [('name', 'sudh'),
#  ('subject', ['DSM', 'big data', 'data analytics', 'programming']),
#  ('batches', ('DSM', 'JDS', 'FSWD')),
#  ('Mentor',
#   {'anurag',
#    'hitesh',
#    'hyder',
#    'krish',
#    'nitin',
#    'sanket',
#    'sudhanshu',
#    'vishwa mohan'}),
#  ('date', {'FSDS': '29th april 23', 'DSM': '6th may23', 'JDS': '13th may23'}),
#  ('batch name', 'BINARY 2.0')]

# %%
d9.clear()

# %%
d9
# Out:
# {}
